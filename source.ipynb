# %%
import pandas as pd
df=pd.read_csv("Viral_Social_Media_Trends.csv")
#print(df)
df.head()
print(df.shape)
# Out:
# (5000, 10)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(df['Platform'])
# Out:
# 0          TikTok
# 1       Instagram
# 2         Twitter
# 3         YouTube
# 4          TikTok
#           ...
# 4995      YouTube
# 4996    Instagram
# 4997      YouTube
# 4998    Instagram
# 4999    Instagram
# Name: Platform, Length: 5000, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Post_ID           5000 non-null   object
#  1   Platform          5000 non-null   object
#  2   Hashtag           5000 non-null   object
#  3   Content_Type      5000 non-null   object
#  4   Region            5000 non-null   object
#  5   Views             5000 non-null   int64
#  6   Likes             5000 non-null   int64
#  7   Shares            5000 non-null   int64
#  8   Comments          5000 non-null   int64
#  9   Engagement_Level  5000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 390.8+ KB

# %%
df.describe(include = 'all')
# Out:
#        Post_ID Platform   Hashtag Content_Type Region         Views  \
# count     5000     5000      5000         5000   5000  5.000000e+03
# unique    5000        4        10            6      8           NaN
# top     Post_1  YouTube  #Fitness  Live Stream    USA           NaN
# freq         1     1324       536          855    677           NaN
# mean       NaN      NaN       NaN          NaN    NaN  2.494066e+06
# std        NaN      NaN       NaN          NaN    NaN  1.459490e+06
# min        NaN      NaN       NaN          NaN    NaN  1.266000e+03
# 25%        NaN      NaN       NaN          NaN    NaN  1.186207e+06
# 50%        NaN      NaN       NaN          NaN    NaN  2.497373e+06
# 75%        NaN      NaN       NaN          NaN    NaN  3.759781e+06
# max        NaN      NaN       NaN          NaN    NaN  4.999430e+06
#
#                 Likes        Shares      Comments Engagement_Level
# count     5000.000000   5000.000000   5000.000000             5000
# ...

# %%
df.describe(include = 'all')
# Out:
#        Post_ID Platform   Hashtag Content_Type Region         Views  \
# count     5000     5000      5000         5000   5000  5.000000e+03
# unique    5000        4        10            6      8           NaN
# top     Post_1  YouTube  #Fitness  Live Stream    USA           NaN
# freq         1     1324       536          855    677           NaN
# mean       NaN      NaN       NaN          NaN    NaN  2.494066e+06
# std        NaN      NaN       NaN          NaN    NaN  1.459490e+06
# min        NaN      NaN       NaN          NaN    NaN  1.266000e+03
# 25%        NaN      NaN       NaN          NaN    NaN  1.186207e+06
# 50%        NaN      NaN       NaN          NaN    NaN  2.497373e+06
# 75%        NaN      NaN       NaN          NaN    NaN  3.759781e+06
# max        NaN      NaN       NaN          NaN    NaN  4.999430e+06
#
#                 Likes        Shares      Comments Engagement_Level
# count     5000.000000   5000.000000   5000.000000             5000
# ...

# %%
import pandas as pd
df=pd.read_csv("Viral_Social_Media_Trends.csv")
print(df)
# Out:
#         Post_ID   Platform     Hashtag Content_Type     Region    Views  \
# 0        Post_1     TikTok  #Challenge        Video         UK  4163464
# 1        Post_2  Instagram  #Education       Shorts      India  4155940
# 2        Post_3    Twitter  #Challenge        Video     Brazil  3666211
# 3        Post_4    YouTube  #Education       Shorts  Australia   917951
# 4        Post_5     TikTok      #Dance         Post     Brazil    64866
# ...         ...        ...         ...          ...        ...      ...
# 4995  Post_4996    YouTube  #Education        Video      Japan  4258236
# 4996  Post_4997  Instagram  #Education        Video         UK  4841525
# 4997  Post_4998    YouTube    #Fashion       Shorts        USA  2004080
# 4998  Post_4999  Instagram     #Gaming       Shorts     Canada  2221665
# 4999  Post_5000  Instagram    #Fashion         Reel      Japan  2224007
#
#        Likes  Shares  Comments Engagement_Level
# 0     339431   53135     19346             High
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.describe(include = 'all')
# Out:
#        Post_ID Platform   Hashtag Content_Type Region         Views  \
# count     5000     5000      5000         5000   5000  5.000000e+03
# unique    5000        4        10            6      8           NaN
# top     Post_1  YouTube  #Fitness  Live Stream    USA           NaN
# freq         1     1324       536          855    677           NaN
# mean       NaN      NaN       NaN          NaN    NaN  2.494066e+06
# std        NaN      NaN       NaN          NaN    NaN  1.459490e+06
# min        NaN      NaN       NaN          NaN    NaN  1.266000e+03
# 25%        NaN      NaN       NaN          NaN    NaN  1.186207e+06
# 50%        NaN      NaN       NaN          NaN    NaN  2.497373e+06
# 75%        NaN      NaN       NaN          NaN    NaN  3.759781e+06
# max        NaN      NaN       NaN          NaN    NaN  4.999430e+06
#
#                 Likes        Shares      Comments Engagement_Level
# count     5000.000000   5000.000000   5000.000000             5000
# ...

# %%
df.hist(figsize=(10,5))
# Out:
# array([[<Axes: title={'center': 'Views'}>,
#         <Axes: title={'center': 'Likes'}>],
#        [<Axes: title={'center': 'Shares'}>,
#         <Axes: title={'center': 'Comments'}>]], dtype=object)

# %%
df['Platform'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Platform'>

# %%
df['Hashtag'].unique()
# Out:
# array(['#Challenge', '#Education', '#Dance', '#Comedy', '#Gaming',
#        '#Music', '#Viral', '#Fitness', '#Tech', '#Fashion'], dtype=object)

# %%
df['Content_Type'].unique()
# Out:
# array(['Video', 'Shorts', 'Post', 'Tweet', 'Live Stream', 'Reel'],
#       dtype=object)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x = 'Platform', data=df)
plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(12, 20))

sns.violinplot(x='Platform', y='Views', data=df, ax=axs[0, 0])
axs[0, 0].set_title('Violin Plot: Views by Platform')

sns.violinplot(x='Platform', y='Likes', data=df, ax=axs[0, 1])
axs[0, 1].set_title('Violin Plot: Likes by Platform')

sns.violinplot(x='Platform', y='Shares', data=df, ax=axs[1, 0])
axs[1, 0].set_title('Violin Plot: Shares by Platform')

sns.violinplot(x='Platform', y='Comments', data=df, ax=axs[1, 1])
axs[1, 1].set_title('Violin Plot: Comments by Platform')

sns.countplot(x='Platform', hue='Engagement_Level', data=df, ax=axs[2, 0])
axs[2, 0].set_title('Engagement Level Count by Platform')

sns.scatterplot(x='Views', y='Likes', hue='Platform', data=df, ax=axs[2, 1])
axs[2, 1].set_title('Views vs Likes Scatter Plot')

plt.tight_layout()
plt.savefig('violin_visualization.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df[['Views', 'Likes', 'Shares', 'Comments']].corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title('Heatmap of Feature Correlations')
plt.savefig('heatmap.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df[['Views', 'Likes', 'Shares', 'Comments']].corr(), annot=True,cmap="coolwarm", linewidths=0.5,linecolor='k')
plt.title('Heatmap of Feature Correlations')
plt.savefig('heatmap.png')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import xgboost as xgb
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
label_encoders = {}
for column in df.select_dtypes(include=['object']).columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# %%
scaler = StandardScaler()
X = df.drop('Engagement_Level', axis=1)
y = df['Engagement_Level']
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=537)

# %%
models = {
    'Random Forest': RandomForestClassifier(),
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Support Vector Machine': SVC(),
    'Naive Bayes': GaussianNB(),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Decision Tree': DecisionTreeClassifier(),
    'Gradient Boosting': GradientBoostingClassifier(),
    'XGBoost': xgb.XGBClassifier (eval_metric='mlogloss')
}

# %%
accuracy_results = {}
for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy_results[model_name] = accuracy_score(y_test, y_pred)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input, Dense
import warnings
warnings.simplefilter("ignore",UserWarning)
nn_model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(len(np.unique(y)), activation='softmax')
])
nn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
nn_model.fit(X_train, y_train, epochs=20, batch_size=16, verbose=0)

# %%
nn_accuracy = nn_model.evaluate(X_test, y_test, verbose=0)[1] * 100
accuracy_results['Neural Network'] = nn_accuracy

# %%
accuracy_df = pd.DataFrame(list(accuracy_results.items()), columns=['Model', 'Accuracy'])

# Visualization
plt.figure(figsize=(12, 6))
sns.barplot(x='Model', y='Accuracy',hue='Model', data=accuracy_df, palette='Blues_r',legend=False)
plt.xlabel('Model')
plt.ylabel('Accuracy (%)')
plt.title('Model Accuracy Comparison')
plt.xticks(rotation=45)
plt.ylim(0, 50)  # Ensuring proper percentage visualization
plt.show()
accuracy_df.sort_values(by='Accuracy', ascending=False)
# Out:
#                     Model   Accuracy
# 8          Neural Network  34.900001
# 4     K-Nearest Neighbors   0.369000
# 2  Support Vector Machine   0.350000
# 0           Random Forest   0.349000
# 7                 XGBoost   0.345000
# 6       Gradient Boosting   0.333000
# 5           Decision Tree   0.325000
# 1     Logistic Regression   0.323000
# 3             Naive Bayes   0.323000
